# %% [markdown]
# <a href="https://colab.research.google.com/github/ArmdBrn/Notebooks_public/blob/main/Random_Walks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as plt
import time

def random_walk(steps):
    position = 0
    walk = [position]

    for i in range(steps):
        move = random.choice([1,-1])
        position += move
        walk.append(position)

        plt.plot(walk)
        plt.title(f"Step {i+1}")
        plt.xlabel("Step Number")
        plt.ylabel("Position")
        plt.ylim(-steps, steps)
        plt.show()
        time.sleep(0.5) # Delay for 0.5 seconds
        plt.clf() # Clear the plot for the next step

random_walk(10)
